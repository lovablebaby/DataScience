# %% [markdown]
# ## drop out + l2 penalty (keras + tf.data 구현) -> 정미연
#
#
# `tf.get_collection / tf.control_dependencies (session의 경우)`

# %% [markdown]
# 출처 : [텐서플로우 공식 블로그] [클릭](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit)

# %% [markdown]
# ### load library

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# %matplotlib inline
# Out:
# /Users/Yeoni/anaconda/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.13.0-dev20190102

# %% [markdown]
# ### Using `keras.layers`, make a baseline model

# %%
basic_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

basic_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

# %% [markdown]
# ### Making a toy datasets

# %%
# datasets
X = np.random.random((1000, 32))
y = np.random.random((1000, 10))

# split training / validation set
tr_X = X[:800]
tr_y = y[:800]
val_X = X[800:]
val_y = y[800:]

# %% [markdown]
# ### tf.data.Dataset.from_tensor_slices
#
# ---
# tf.data.Dataset 를 생성하는 함수로 입력된 텐서로부터 slices를 생성합니다. 예를 들어 MNIST의 학습데이터 (60000, 28, 28)가 입력되면, 60000개의 slices로 만들고 각각의 slice는 28×28의 이미지 크기를 갖게 됩니다

# %%
dataset = tf.data.Dataset.from_tensor_slices((tr_X, tr_y))
dataset = dataset.batch(32)
dataset = dataset.repeat()

# fit
basic_model.fit(dataset, epochs=10, steps_per_epoch=20)
# Out:
# Epoch 1/10
# 20/20 [==============================] - 0s 19ms/step - loss: 0.6931 - acc: 0.0000e+00 - binary_crossentropy: 0.6931
# Epoch 2/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6930 - acc: 0.0000e+00 - binary_crossentropy: 0.6930
# Epoch 3/10
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6930 - acc: 0.0000e+00 - binary_crossentropy: 0.6930
# Epoch 4/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6929 - acc: 0.0000e+00 - binary_crossentropy: 0.6929
# Epoch 5/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6929 - acc: 0.0000e+00 - binary_crossentropy: 0.6929
# Epoch 6/10
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6929 - acc: 0.0000e+00 - binary_crossentropy: 0.6929
# Epoch 7/10
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6929 - acc: 0.0000e+00 - binary_crossentropy: 0.6929
# Epoch 8/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6928 - acc: 0.0000e+00 - binary_crossentropy: 0.6928
# Epoch 9/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6928 - acc: 0.0000e+00 - binary_crossentropy: 0.6928
# Epoch 10/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6927 - acc: 0.0000e+00 - binary_crossentropy: 0.6927

# %% [markdown]
# #### validation set

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((val_X, val_y))
val_dataset = val_dataset.batch(32).repeat()

# fit
basic_model.fit(dataset, epochs=10, steps_per_epoch=30,
          validation_data=val_dataset,
          validation_steps=3)
# Out:
# Epoch 1/10
# 30/30 [==============================] - 0s 6ms/step - loss: 0.6927 - acc: 0.0000e+00 - binary_crossentropy: 0.6927 - val_loss: 0.6932 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 2/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6926 - acc: 0.0000e+00 - binary_crossentropy: 0.6926 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6940
# Epoch 3/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6925 - acc: 0.0000e+00 - binary_crossentropy: 0.6925 - val_loss: 0.6928 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6929
# Epoch 4/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6924 - acc: 0.0000e+00 - binary_crossentropy: 0.6924 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6940
# Epoch 5/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6924 - acc: 0.0000e+00 - binary_crossentropy: 0.6924 - val_loss: 0.6929 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6931
# Epoch 6/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6923 - acc: 0.0000e+00 - binary_crossentropy: 0.6923 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6936
# Epoch 7/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6923 - acc: 0.0000e+00 - binary_crossentropy: 0.6923 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6944
# Epoch 8/10
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6922 - acc: 0.0000e+00 - binary_crossentropy: 0.6922 - val_loss: 0.6934 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 9/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6921 - acc: 0.0000e+00 - binary_crossentropy: 0.6921 - val_loss: 0.6943 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6943
# Epoch 10/10
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6921 - acc: 0.0000e+00 - binary_crossentropy: 0.6921 - val_loss: 0.6928 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6930

# %%
basic_model.evaluate(X, y, batch_size=32)

basic_model.evaluate(dataset, steps=30)
# Out:
#  1/30 [>.............................] - ETA: 2s - loss: 0.6923 - acc: 0.0000e+00 - binary_crossentropy: 0.69236923
# [0.692011684179306, 0.0, 0.6920118]

# %% [markdown]
# ### dropout+l2 model

# %%
basic_drop_l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), # l2 layer
                       activation=tf.nn.relu),
    keras.layers.Dropout(0.5), # dropout layer
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), # l2 layer
                       activation=tf.nn.relu),
    keras.layers.Dropout(0.5),# dropout layer
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

basic_drop_l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])


basic_drop_l2_model_history = basic_drop_l2_model.fit(tr_X, tr_y,
                                  epochs=20,
                                  batch_size=50,
                                  validation_data=(val_X, val_y),
                                  verbose=2)
# Out:
# WARNING:tensorflow:From /Users/Yeoni/anaconda/lib/python3.5/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 800 samples, validate on 200 samples
# Epoch 1/20
#  - 0s - loss: 0.7699 - acc: 0.0000e+00 - binary_crossentropy: 0.7340 - val_loss: 0.7298 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6947
# Epoch 2/20
#  - 0s - loss: 0.7438 - acc: 0.0000e+00 - binary_crossentropy: 0.7095 - val_loss: 0.7267 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 3/20
#  - 0s - loss: 0.7346 - acc: 0.0000e+00 - binary_crossentropy: 0.7021 - val_loss: 0.7252 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6935
# Epoch 4/20
#  - 0s - loss: 0.7299 - acc: 0.0000e+00 - binary_crossentropy: 0.6990 - val_loss: 0.7237 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6936
# Epoch 5/20
#  - 0s - loss: 0.7277 - acc: 0.0000e+00 - binary_crossentropy: 0.6984 - val_loss: 0.7221 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6936
# Epoch 6/20
#  - 0s - loss: 0.7242 - acc: 0.0000e+00 - binary_crossentropy: 0.6964 - val_loss: 0.7205 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6935
# Epoch 7/20
#  - 0s - loss: 0.7216 - acc: 0.0000e+00 - binary_crossentropy: 0.6953 - val_loss: 0.7190 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6935
# Epoch 8/20
#  - 0s - loss: 0.7202 - acc: 0.0000e+00 - binary_crossentropy: 0.6952 - val_loss: 0.7177 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 9/20
#  - 0s - loss: 0.7186 - acc: 0.0000e+00 - binary_crossentropy: 0.6950 - val_loss: 0.7164 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 10/20
#  - 0s - loss: 0.7166 - acc: 0.0000e+00 - binary_crossentropy: 0.6942 - val_loss: 0.7152 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 11/20
#  - 0s - loss: 0.7152 - acc: 0.0000e+00 - binary_crossentropy: 0.6940 - val_loss: 0.7140 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 12/20
#  - 0s - loss: 0.7141 - acc: 0.0000e+00 - binary_crossentropy: 0.6940 - val_loss: 0.7129 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933
# Epoch 13/20
#  - 0s - loss: 0.7130 - acc: 0.0000e+00 - binary_crossentropy: 0.6939 - val_loss: 0.7119 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933
# Epoch 14/20
#  - 0s - loss: 0.7120 - acc: 0.0000e+00 - binary_crossentropy: 0.6939 - val_loss: 0.7110 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933
# Epoch 15/20
#  - 0s - loss: 0.7109 - acc: 0.0000e+00 - binary_crossentropy: 0.6936 - val_loss: 0.7101 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 16/20
#  - 0s - loss: 0.7098 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7092 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933
# Epoch 17/20
#  - 0s - loss: 0.7090 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7084 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933
# Epoch 18/20
#  - 0s - loss: 0.7081 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7077 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933
# Epoch 19/20
#  - 0s - loss: 0.7075 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7069 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933
# Epoch 20/20
#  - 0s - loss: 0.7067 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7063 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6933

# %% [markdown]
# ## example. l2+dropout model with MNIST

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.imdb.load_data(num_words=NUM_WORDS)

# %%
def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=10,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
#  - 7s - loss: 0.4819 - acc: 0.8157 - binary_crossentropy: 0.4819 - val_loss: 0.3353 - val_acc: 0.8776 - val_binary_crossentropy: 0.3353
# Epoch 2/10
#  - 6s - loss: 0.2508 - acc: 0.9115 - binary_crossentropy: 0.2508 - val_loss: 0.2847 - val_acc: 0.8888 - val_binary_crossentropy: 0.2847
# Epoch 3/10
#  - 4s - loss: 0.1851 - acc: 0.9346 - binary_crossentropy: 0.1851 - val_loss: 0.2883 - val_acc: 0.8862 - val_binary_crossentropy: 0.2883
# Epoch 4/10
#  - 4s - loss: 0.1500 - acc: 0.9482 - binary_crossentropy: 0.1500 - val_loss: 0.3164 - val_acc: 0.8760 - val_binary_crossentropy: 0.3164
# Epoch 5/10
#  - 4s - loss: 0.1235 - acc: 0.9591 - binary_crossentropy: 0.1235 - val_loss: 0.3315 - val_acc: 0.8760 - val_binary_crossentropy: 0.3315
# Epoch 6/10
#  - 4s - loss: 0.1023 - acc: 0.9686 - binary_crossentropy: 0.1023 - val_loss: 0.3619 - val_acc: 0.8715 - val_binary_crossentropy: 0.3619
# Epoch 7/10
#  - 4s - loss: 0.0855 - acc: 0.9741 - binary_crossentropy: 0.0855 - val_loss: 0.3963 - val_acc: 0.8678 - val_binary_crossentropy: 0.3963
# Epoch 8/10
#  - 4s - loss: 0.0726 - acc: 0.9802 - binary_crossentropy: 0.0726 - val_loss: 0.4317 - val_acc: 0.8641 - val_binary_crossentropy: 0.4317
# Epoch 9/10
#  - 4s - loss: 0.0589 - acc: 0.9860 - binary_crossentropy: 0.0589 - val_loss: 0.4715 - val_acc: 0.8632 - val_binary_crossentropy: 0.4715
# Epoch 10/10
#  - 4s - loss: 0.0502 - acc: 0.9888 - binary_crossentropy: 0.0502 - val_loss: 0.5104 - val_acc: 0.8593 - val_binary_crossentropy: 0.5104

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 4)                 40004
# _________________________________________________________________
# dense_22 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 4s - loss: 0.6500 - acc: 0.6259 - binary_crossentropy: 0.6500 - val_loss: 0.6015 - val_acc: 0.7144 - val_binary_crossentropy: 0.6015
# Epoch 2/20
#  - 3s - loss: 0.5426 - acc: 0.8012 - binary_crossentropy: 0.5426 - val_loss: 0.5085 - val_acc: 0.8208 - val_binary_crossentropy: 0.5085
# Epoch 3/20
#  - 4s - loss: 0.4303 - acc: 0.8827 - binary_crossentropy: 0.4303 - val_loss: 0.4060 - val_acc: 0.8732 - val_binary_crossentropy: 0.4060
# Epoch 4/20
#  - 5s - loss: 0.3274 - acc: 0.9099 - binary_crossentropy: 0.3274 - val_loss: 0.3395 - val_acc: 0.8833 - val_binary_crossentropy: 0.3395
# Epoch 5/20
#  - 5s - loss: 0.2641 - acc: 0.9199 - binary_crossentropy: 0.2641 - val_loss: 0.3070 - val_acc: 0.8854 - val_binary_crossentropy: 0.3070
# Epoch 6/20
#  - 5s - loss: 0.2252 - acc: 0.9296 - binary_crossentropy: 0.2252 - val_loss: 0.2904 - val_acc: 0.8884 - val_binary_crossentropy: 0.2904
# Epoch 7/20
#  - 4s - loss: 0.1954 - acc: 0.9364 - binary_crossentropy: 0.1954 - val_loss: 0.2831 - val_acc: 0.8885 - val_binary_crossentropy: 0.2831
# Epoch 8/20
#  - 3s - loss: 0.1716 - acc: 0.9434 - binary_crossentropy: 0.1716 - val_loss: 0.2855 - val_acc: 0.8864 - val_binary_crossentropy: 0.2855
# Epoch 9/20
#  - 3s - loss: 0.1530 - acc: 0.9492 - binary_crossentropy: 0.1530 - val_loss: 0.2913 - val_acc: 0.8852 - val_binary_crossentropy: 0.2913
# Epoch 10/20
#  - 3s - loss: 0.1378 - acc: 0.9559 - binary_crossentropy: 0.1378 - val_loss: 0.3025 - val_acc: 0.8823 - val_binary_crossentropy: 0.3025
# Epoch 11/20
#  - 3s - loss: 0.1256 - acc: 0.9602 - binary_crossentropy: 0.1256 - val_loss: 0.3136 - val_acc: 0.8793 - val_binary_crossentropy: 0.3136
# Epoch 12/20
#  - 3s - loss: 0.1149 - acc: 0.9644 - binary_crossentropy: 0.1149 - val_loss: 0.3282 - val_acc: 0.8765 - val_binary_crossentropy: 0.3282
# Epoch 13/20
#  - 3s - loss: 0.1052 - acc: 0.9686 - binary_crossentropy: 0.1052 - val_loss: 0.3391 - val_acc: 0.8762 - val_binary_crossentropy: 0.3391
# Epoch 14/20
#  - 3s - loss: 0.0964 - acc: 0.9724 - binary_crossentropy: 0.0964 - val_loss: 0.3547 - val_acc: 0.8737 - val_binary_crossentropy: 0.3547
# Epoch 15/20
#  - 3s - loss: 0.0890 - acc: 0.9740 - binary_crossentropy: 0.0890 - val_loss: 0.3676 - val_acc: 0.8727 - val_binary_crossentropy: 0.3676
# Epoch 16/20
#  - 3s - loss: 0.0820 - acc: 0.9779 - binary_crossentropy: 0.0820 - val_loss: 0.3835 - val_acc: 0.8713 - val_binary_crossentropy: 0.3835
# Epoch 17/20
#  - 3s - loss: 0.0755 - acc: 0.9800 - binary_crossentropy: 0.0755 - val_loss: 0.4000 - val_acc: 0.8701 - val_binary_crossentropy: 0.4000
# Epoch 18/20
#  - 3s - loss: 0.0689 - acc: 0.9829 - binary_crossentropy: 0.0689 - val_loss: 0.4199 - val_acc: 0.8670 - val_binary_crossentropy: 0.4199
# Epoch 19/20
#  - 3s - loss: 0.0634 - acc: 0.9853 - binary_crossentropy: 0.0634 - val_loss: 0.4434 - val_acc: 0.8644 - val_binary_crossentropy: 0.4434
# Epoch 20/20
#  - 3s - loss: 0.0583 - acc: 0.9872 - binary_crossentropy: 0.0583 - val_loss: 0.4568 - val_acc: 0.8653 - val_binary_crossentropy: 0.4568

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 512)               5120512
# _________________________________________________________________
# dense_25 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 26s - loss: 0.2524 - acc: 0.9004 - binary_crossentropy: 0.2524 - val_loss: 0.2854 - val_acc: 0.8844 - val_binary_crossentropy: 0.2854
# Epoch 2/20
#  - 19s - loss: 0.0983 - acc: 0.9660 - binary_crossentropy: 0.0983 - val_loss: 0.3446 - val_acc: 0.8744 - val_binary_crossentropy: 0.3446
# Epoch 3/20
#  - 18s - loss: 0.0190 - acc: 0.9956 - binary_crossentropy: 0.0190 - val_loss: 0.4919 - val_acc: 0.8691 - val_binary_crossentropy: 0.4919
# Epoch 4/20
#  - 17s - loss: 0.0025 - acc: 0.9998 - binary_crossentropy: 0.0025 - val_loss: 0.6510 - val_acc: 0.8716 - val_binary_crossentropy: 0.6510
# Epoch 5/20
#  - 17s - loss: 3.7871e-04 - acc: 1.0000 - binary_crossentropy: 3.7871e-04 - val_loss: 0.6956 - val_acc: 0.8727 - val_binary_crossentropy: 0.6956
# Epoch 6/20
#  - 17s - loss: 1.5729e-04 - acc: 1.0000 - binary_crossentropy: 1.5729e-04 - val_loss: 0.7339 - val_acc: 0.8730 - val_binary_crossentropy: 0.7339
# Epoch 7/20
#  - 17s - loss: 1.0516e-04 - acc: 1.0000 - binary_crossentropy: 1.0516e-04 - val_loss: 0.7618 - val_acc: 0.8727 - val_binary_crossentropy: 0.7618
# Epoch 8/20
#  - 17s - loss: 7.8534e-05 - acc: 1.0000 - binary_crossentropy: 7.8534e-05 - val_loss: 0.7826 - val_acc: 0.8731 - val_binary_crossentropy: 0.7826
# Epoch 9/20
#  - 17s - loss: 6.1566e-05 - acc: 1.0000 - binary_crossentropy: 6.1566e-05 - val_loss: 0.7997 - val_acc: 0.8730 - val_binary_crossentropy: 0.7997
# Epoch 10/20
#  - 17s - loss: 4.9938e-05 - acc: 1.0000 - binary_crossentropy: 4.9938e-05 - val_loss: 0.8152 - val_acc: 0.8733 - val_binary_crossentropy: 0.8152
# Epoch 11/20
#  - 17s - loss: 4.1407e-05 - acc: 1.0000 - binary_crossentropy: 4.1407e-05 - val_loss: 0.8288 - val_acc: 0.8734 - val_binary_crossentropy: 0.8288
# Epoch 12/20
#  - 18s - loss: 3.4755e-05 - acc: 1.0000 - binary_crossentropy: 3.4755e-05 - val_loss: 0.8414 - val_acc: 0.8734 - val_binary_crossentropy: 0.8414
# Epoch 13/20
#  - 17s - loss: 2.9625e-05 - acc: 1.0000 - binary_crossentropy: 2.9625e-05 - val_loss: 0.8531 - val_acc: 0.8736 - val_binary_crossentropy: 0.8531
# Epoch 14/20
#  - 18s - loss: 2.5578e-05 - acc: 1.0000 - binary_crossentropy: 2.5578e-05 - val_loss: 0.8638 - val_acc: 0.8735 - val_binary_crossentropy: 0.8638
# Epoch 15/20
#  - 22s - loss: 2.2238e-05 - acc: 1.0000 - binary_crossentropy: 2.2238e-05 - val_loss: 0.8742 - val_acc: 0.8736 - val_binary_crossentropy: 0.8742
# Epoch 16/20
#  - 17s - loss: 1.9480e-05 - acc: 1.0000 - binary_crossentropy: 1.9480e-05 - val_loss: 0.8842 - val_acc: 0.8738 - val_binary_crossentropy: 0.8842
# Epoch 17/20
#  - 18s - loss: 1.7156e-05 - acc: 1.0000 - binary_crossentropy: 1.7156e-05 - val_loss: 0.8937 - val_acc: 0.8739 - val_binary_crossentropy: 0.8937
# Epoch 18/20
#  - 17s - loss: 1.5190e-05 - acc: 1.0000 - binary_crossentropy: 1.5190e-05 - val_loss: 0.9026 - val_acc: 0.8737 - val_binary_crossentropy: 0.9026
# Epoch 19/20
#  - 16s - loss: 1.3516e-05 - acc: 1.0000 - binary_crossentropy: 1.3516e-05 - val_loss: 0.9114 - val_acc: 0.8739 - val_binary_crossentropy: 0.9114
# Epoch 20/20
#  - 17s - loss: 1.2073e-05 - acc: 1.0000 - binary_crossentropy: 1.2073e-05 - val_loss: 0.9198 - val_acc: 0.8738 - val_binary_crossentropy: 0.9198

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 9s - loss: 0.5473 - acc: 0.7924 - binary_crossentropy: 0.5078 - val_loss: 0.4076 - val_acc: 0.8707 - val_binary_crossentropy: 0.3644
# Epoch 2/20
#  - 7s - loss: 0.3267 - acc: 0.9043 - binary_crossentropy: 0.2771 - val_loss: 0.3426 - val_acc: 0.8876 - val_binary_crossentropy: 0.2887
# Epoch 3/20
#  - 4s - loss: 0.2714 - acc: 0.9232 - binary_crossentropy: 0.2145 - val_loss: 0.3423 - val_acc: 0.8853 - val_binary_crossentropy: 0.2834
# Epoch 4/20
#  - 4s - loss: 0.2454 - acc: 0.9361 - binary_crossentropy: 0.1848 - val_loss: 0.3514 - val_acc: 0.8833 - val_binary_crossentropy: 0.2896
# Epoch 5/20
#  - 4s - loss: 0.2311 - acc: 0.9414 - binary_crossentropy: 0.1679 - val_loss: 0.3645 - val_acc: 0.8794 - val_binary_crossentropy: 0.3006
# Epoch 6/20
#  - 4s - loss: 0.2204 - acc: 0.9465 - binary_crossentropy: 0.1556 - val_loss: 0.3764 - val_acc: 0.8766 - val_binary_crossentropy: 0.3110
# Epoch 7/20
#  - 4s - loss: 0.2112 - acc: 0.9505 - binary_crossentropy: 0.1451 - val_loss: 0.3896 - val_acc: 0.8734 - val_binary_crossentropy: 0.3231
# Epoch 8/20
#  - 4s - loss: 0.2034 - acc: 0.9531 - binary_crossentropy: 0.1363 - val_loss: 0.4053 - val_acc: 0.8702 - val_binary_crossentropy: 0.3381
# Epoch 9/20
#  - 4s - loss: 0.1987 - acc: 0.9543 - binary_crossentropy: 0.1311 - val_loss: 0.4215 - val_acc: 0.8681 - val_binary_crossentropy: 0.3533
# Epoch 10/20
#  - 4s - loss: 0.1944 - acc: 0.9568 - binary_crossentropy: 0.1257 - val_loss: 0.4290 - val_acc: 0.8668 - val_binary_crossentropy: 0.3599
# Epoch 11/20
#  - 4s - loss: 0.1884 - acc: 0.9602 - binary_crossentropy: 0.1190 - val_loss: 0.4415 - val_acc: 0.8663 - val_binary_crossentropy: 0.3721
# Epoch 12/20
#  - 4s - loss: 0.1832 - acc: 0.9611 - binary_crossentropy: 0.1134 - val_loss: 0.4520 - val_acc: 0.8634 - val_binary_crossentropy: 0.3820
# Epoch 13/20
#  - 4s - loss: 0.1811 - acc: 0.9619 - binary_crossentropy: 0.1109 - val_loss: 0.4638 - val_acc: 0.8626 - val_binary_crossentropy: 0.3935
# Epoch 14/20
#  - 4s - loss: 0.1771 - acc: 0.9636 - binary_crossentropy: 0.1065 - val_loss: 0.4774 - val_acc: 0.8600 - val_binary_crossentropy: 0.4064
# Epoch 15/20
#  - 4s - loss: 0.1753 - acc: 0.9643 - binary_crossentropy: 0.1038 - val_loss: 0.5048 - val_acc: 0.8558 - val_binary_crossentropy: 0.4329
# Epoch 16/20
#  - 4s - loss: 0.1743 - acc: 0.9626 - binary_crossentropy: 0.1017 - val_loss: 0.4969 - val_acc: 0.8595 - val_binary_crossentropy: 0.4241
# Epoch 17/20
#  - 4s - loss: 0.1697 - acc: 0.9662 - binary_crossentropy: 0.0970 - val_loss: 0.5164 - val_acc: 0.8556 - val_binary_crossentropy: 0.4434
# Epoch 18/20
#  - 4s - loss: 0.1656 - acc: 0.9688 - binary_crossentropy: 0.0925 - val_loss: 0.5155 - val_acc: 0.8589 - val_binary_crossentropy: 0.4424
# Epoch 19/20
#  - 4s - loss: 0.1611 - acc: 0.9691 - binary_crossentropy: 0.0882 - val_loss: 0.5231 - val_acc: 0.8576 - val_binary_crossentropy: 0.4506
# Epoch 20/20
#  - 4s - loss: 0.1583 - acc: 0.9712 - binary_crossentropy: 0.0856 - val_loss: 0.5405 - val_acc: 0.8558 - val_binary_crossentropy: 0.4677

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=30,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 12s - loss: 0.4636 - acc: 0.7792 - binary_crossentropy: 0.4636 - val_loss: 0.3038 - val_acc: 0.8793 - val_binary_crossentropy: 0.3038
# Epoch 2/20
#  - 9s - loss: 0.3071 - acc: 0.8790 - binary_crossentropy: 0.3071 - val_loss: 0.2873 - val_acc: 0.8826 - val_binary_crossentropy: 0.2873
# Epoch 3/20
#  - 8s - loss: 0.2529 - acc: 0.9047 - binary_crossentropy: 0.2529 - val_loss: 0.2929 - val_acc: 0.8831 - val_binary_crossentropy: 0.2929
# Epoch 4/20
#  - 8s - loss: 0.2307 - acc: 0.9136 - binary_crossentropy: 0.2307 - val_loss: 0.3053 - val_acc: 0.8780 - val_binary_crossentropy: 0.3053
# Epoch 5/20
#  - 7s - loss: 0.2059 - acc: 0.9205 - binary_crossentropy: 0.2059 - val_loss: 0.3214 - val_acc: 0.8792 - val_binary_crossentropy: 0.3214
# Epoch 6/20
#  - 7s - loss: 0.1874 - acc: 0.9275 - binary_crossentropy: 0.1874 - val_loss: 0.3713 - val_acc: 0.8762 - val_binary_crossentropy: 0.3713
# Epoch 7/20
#  - 7s - loss: 0.1746 - acc: 0.9306 - binary_crossentropy: 0.1746 - val_loss: 0.3892 - val_acc: 0.8750 - val_binary_crossentropy: 0.3892
# Epoch 8/20
#  - 8s - loss: 0.1697 - acc: 0.9340 - binary_crossentropy: 0.1697 - val_loss: 0.3964 - val_acc: 0.8750 - val_binary_crossentropy: 0.3964
# Epoch 9/20
#  - 8s - loss: 0.1631 - acc: 0.9363 - binary_crossentropy: 0.1631 - val_loss: 0.4209 - val_acc: 0.8750 - val_binary_crossentropy: 0.4209
# Epoch 10/20
#  - 7s - loss: 0.1511 - acc: 0.9389 - binary_crossentropy: 0.1511 - val_loss: 0.5126 - val_acc: 0.8752 - val_binary_crossentropy: 0.5126
# Epoch 11/20
#  - 7s - loss: 0.1440 - acc: 0.9422 - binary_crossentropy: 0.1440 - val_loss: 0.4962 - val_acc: 0.8723 - val_binary_crossentropy: 0.4962
# Epoch 12/20
#  - 7s - loss: 0.1350 - acc: 0.9448 - binary_crossentropy: 0.1350 - val_loss: 0.5425 - val_acc: 0.8739 - val_binary_crossentropy: 0.5425
# Epoch 13/20
#  - 7s - loss: 0.1365 - acc: 0.9437 - binary_crossentropy: 0.1365 - val_loss: 0.5531 - val_acc: 0.8731 - val_binary_crossentropy: 0.5531
# Epoch 14/20
#  - 7s - loss: 0.1263 - acc: 0.9472 - binary_crossentropy: 0.1263 - val_loss: 0.5891 - val_acc: 0.8727 - val_binary_crossentropy: 0.5891
# Epoch 15/20
#  - 7s - loss: 0.1330 - acc: 0.9426 - binary_crossentropy: 0.1330 - val_loss: 0.5980 - val_acc: 0.8726 - val_binary_crossentropy: 0.5980
# Epoch 16/20
#  - 7s - loss: 0.1269 - acc: 0.9472 - binary_crossentropy: 0.1269 - val_loss: 0.6570 - val_acc: 0.8726 - val_binary_crossentropy: 0.6570
# Epoch 17/20
#  - 7s - loss: 0.1224 - acc: 0.9470 - binary_crossentropy: 0.1224 - val_loss: 0.6684 - val_acc: 0.8706 - val_binary_crossentropy: 0.6684
# Epoch 18/20
#  - 7s - loss: 0.1216 - acc: 0.9495 - binary_crossentropy: 0.1216 - val_loss: 0.6535 - val_acc: 0.8719 - val_binary_crossentropy: 0.6535
# Epoch 19/20
#  - 7s - loss: 0.1188 - acc: 0.9494 - binary_crossentropy: 0.1188 - val_loss: 0.6640 - val_acc: 0.8735 - val_binary_crossentropy: 0.6640
# Epoch 20/20
#  - 7s - loss: 0.1177 - acc: 0.9482 - binary_crossentropy: 0.1177 - val_loss: 0.6652 - val_acc: 0.8701 - val_binary_crossentropy: 0.6652

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
