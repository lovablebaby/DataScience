# %% [markdown]
# ## drop out + l2 penalty (keras + tf.data 구현) -> 정미연
#
#
# `tf.get_collection / tf.control_dependencies (session의 경우)`

# %% [markdown]
# 출처 : [텐서플로우 공식 블로그] [클릭](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit)

# %% [markdown]
# ### load library

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# %matplotlib inline
# Out:
# /Users/Yeoni/anaconda/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.13.0-dev20190102

# %% [markdown]
# ### Using `keras.layers`, make a baseline model

# %%
basic_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

basic_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])
# Out:
# WARNING:tensorflow:From /Users/Yeoni/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/init_ops.py:1253: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/Yeoni/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/resource_variable_ops.py:439: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Making a toy datasets

# %%
# datasets
X = np.random.random((1000, 32))
y = np.random.random((1000, 10))

# split training / validation set
tr_X = X[:800]
tr_y = y[:800]
val_X = X[800:]
val_y = y[800:]

# %% [markdown]
# ### tf.data.Dataset.from_tensor_slices
#
# ---
# tf.data.Dataset 를 생성하는 함수로 입력된 텐서로부터 slices를 생성합니다. 예를 들어 MNIST의 학습데이터 (60000, 28, 28)가 입력되면, 60000개의 slices로 만들고 각각의 slice는 28×28의 이미지 크기를 갖게 됩니다

# %%
dataset = tf.data.Dataset.from_tensor_slices((tr_X, tr_y))
dataset = dataset.batch(32)
dataset = dataset.repeat()

# fit
basic_model.fit(dataset, epochs=10, steps_per_epoch=20)
# Out:
# WARNING:tensorflow:From /Users/Yeoni/anaconda/lib/python3.5/site-packages/tensorflow/python/data/ops/dataset_ops.py:1761: DatasetV1.make_initializable_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_initializable_iterator(dataset)`.
# WARNING:tensorflow:From /Users/Yeoni/anaconda/lib/python3.5/site-packages/tensorflow/python/keras/engine/base_layer_utils.py:125: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/Yeoni/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3067: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6974 - acc: 0.0000e+00 - binary_crossentropy: 0.6974
# Epoch 2/10
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6952 - acc: 0.0000e+00 - binary_crossentropy: 0.6952
# Epoch 3/10
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6941 - acc: 0.0000e+00 - binary_crossentropy: 0.6941
# Epoch 4/10
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6939 - acc: 0.0000e+00 - binary_crossentropy: 0.6939
# Epoch 5/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6935 - acc: 0.0000e+00 - binary_crossentropy: 0.6935
# Epoch 6/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6934 - acc: 0.0000e+00 - binary_crossentropy: 0.6934
# Epoch 7/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6932 - acc: 0.0000e+00 - binary_crossentropy: 0.6932
# Epoch 8/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6930 - acc: 0.0000e+00 - binary_crossentropy: 0.6930
# Epoch 9/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6931 - acc: 0.0000e+00 - binary_crossentropy: 0.6931
# Epoch 10/10
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6928 - acc: 0.0000e+00 - binary_crossentropy: 0.6928

# %% [markdown]
# #### validation set

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((val_X, val_y))
val_dataset = val_dataset.batch(32).repeat()

# fit
basic_model.fit(dataset, epochs=10, steps_per_epoch=30,
          validation_data=val_dataset,
          validation_steps=3)
# Out:
# Epoch 1/10
# 30/30 [==============================] - 0s 15ms/step - loss: 0.6928 - acc: 0.0000e+00 - binary_crossentropy: 0.6928 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6935
# Epoch 2/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6926 - acc: 0.0000e+00 - binary_crossentropy: 0.6926 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6939
# Epoch 3/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6926 - acc: 0.0000e+00 - binary_crossentropy: 0.6926 - val_loss: 0.6928 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 4/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6925 - acc: 0.0000e+00 - binary_crossentropy: 0.6925 - val_loss: 0.6930 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6930
# Epoch 5/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6923 - acc: 0.0000e+00 - binary_crossentropy: 0.6923 - val_loss: 0.6931 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6941
# Epoch 6/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6923 - acc: 0.0000e+00 - binary_crossentropy: 0.6923 - val_loss: 0.6930 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6930
# Epoch 7/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6921 - acc: 0.0000e+00 - binary_crossentropy: 0.6921 - val_loss: 0.6933 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6939
# Epoch 8/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6921 - acc: 0.0000e+00 - binary_crossentropy: 0.6921 - val_loss: 0.6932 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 9/10
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6920 - acc: 0.0000e+00 - binary_crossentropy: 0.6920 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6939
# Epoch 10/10
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6918 - acc: 0.0000e+00 - binary_crossentropy: 0.6918 - val_loss: 0.6929 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6937

# %%
basic_model.evaluate(X, y, batch_size=32)

basic_model.evaluate(dataset, steps=30)
# Out:
#  1/30 [>.............................] - ETA: 2s - loss: 0.6929 - acc: 0.0000e+00 - binary_crossentropy: 0.69296929
# [0.6917103270689646, 0.0, 0.6917104]

# %% [markdown]
# ### dropout+l2 model

# %%
basic_drop_l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), # l2 layer
                       activation=tf.nn.relu),
    keras.layers.Dropout(0.5), # dropout layer
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001), # l2 layer
                       activation=tf.nn.relu),
    keras.layers.Dropout(0.5),# dropout layer
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

basic_drop_l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])


basic_drop_l2_model_history = basic_drop_l2_model.fit(tr_X, tr_y,
                                  epochs=20,
                                  batch_size=50,
                                  validation_data=(val_X, val_y),
                                  verbose=2)
# Out:
# WARNING:tensorflow:From /Users/Yeoni/anaconda/lib/python3.5/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 800 samples, validate on 200 samples
# Epoch 1/20
#  - 0s - loss: 0.7813 - acc: 0.0000e+00 - binary_crossentropy: 0.7435 - val_loss: 0.7339 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6972
# Epoch 2/20
#  - 0s - loss: 0.7544 - acc: 0.0000e+00 - binary_crossentropy: 0.7186 - val_loss: 0.7304 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6956
# Epoch 3/20
#  - 0s - loss: 0.7407 - acc: 0.0000e+00 - binary_crossentropy: 0.7068 - val_loss: 0.7276 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6946
# Epoch 4/20
#  - 0s - loss: 0.7342 - acc: 0.0000e+00 - binary_crossentropy: 0.7020 - val_loss: 0.7253 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6940
# Epoch 5/20
#  - 0s - loss: 0.7288 - acc: 0.0000e+00 - binary_crossentropy: 0.6983 - val_loss: 0.7233 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6936
# Epoch 6/20
#  - 0s - loss: 0.7250 - acc: 0.0000e+00 - binary_crossentropy: 0.6960 - val_loss: 0.7215 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6934
# Epoch 7/20
#  - 0s - loss: 0.7242 - acc: 0.0000e+00 - binary_crossentropy: 0.6967 - val_loss: 0.7199 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 8/20
#  - 0s - loss: 0.7214 - acc: 0.0000e+00 - binary_crossentropy: 0.6953 - val_loss: 0.7186 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 9/20
#  - 0s - loss: 0.7192 - acc: 0.0000e+00 - binary_crossentropy: 0.6944 - val_loss: 0.7173 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 10/20
#  - 0s - loss: 0.7173 - acc: 0.0000e+00 - binary_crossentropy: 0.6938 - val_loss: 0.7161 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 11/20
#  - 0s - loss: 0.7165 - acc: 0.0000e+00 - binary_crossentropy: 0.6941 - val_loss: 0.7150 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 12/20
#  - 0s - loss: 0.7147 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7140 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 13/20
#  - 0s - loss: 0.7138 - acc: 0.0000e+00 - binary_crossentropy: 0.6935 - val_loss: 0.7130 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 14/20
#  - 0s - loss: 0.7128 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7121 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 15/20
#  - 0s - loss: 0.7120 - acc: 0.0000e+00 - binary_crossentropy: 0.6935 - val_loss: 0.7112 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 16/20
#  - 0s - loss: 0.7110 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7104 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 17/20
#  - 0s - loss: 0.7102 - acc: 0.0000e+00 - binary_crossentropy: 0.6934 - val_loss: 0.7096 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 18/20
#  - 0s - loss: 0.7094 - acc: 0.0000e+00 - binary_crossentropy: 0.6933 - val_loss: 0.7089 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 19/20
#  - 0s - loss: 0.7085 - acc: 0.0000e+00 - binary_crossentropy: 0.6931 - val_loss: 0.7082 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932
# Epoch 20/20
#  - 0s - loss: 0.7079 - acc: 0.0000e+00 - binary_crossentropy: 0.6932 - val_loss: 0.7076 - val_acc: 0.0000e+00 - val_binary_crossentropy: 0.6932

# %% [markdown]
# ## example. l2+dropout model with MNIST

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.imdb.load_data(num_words=NUM_WORDS)

# %%
def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=10,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
#  - 8s - loss: 0.4904 - acc: 0.7945 - binary_crossentropy: 0.4904 - val_loss: 0.3396 - val_acc: 0.8756 - val_binary_crossentropy: 0.3396
# Epoch 2/10
#  - 5s - loss: 0.2504 - acc: 0.9129 - binary_crossentropy: 0.2504 - val_loss: 0.2850 - val_acc: 0.8877 - val_binary_crossentropy: 0.2850
# Epoch 3/10
#  - 5s - loss: 0.1821 - acc: 0.9368 - binary_crossentropy: 0.1821 - val_loss: 0.2922 - val_acc: 0.8842 - val_binary_crossentropy: 0.2922
# Epoch 4/10
#  - 4s - loss: 0.1475 - acc: 0.9500 - binary_crossentropy: 0.1475 - val_loss: 0.3227 - val_acc: 0.8748 - val_binary_crossentropy: 0.3227
# Epoch 5/10
#  - 4s - loss: 0.1211 - acc: 0.9602 - binary_crossentropy: 0.1211 - val_loss: 0.3362 - val_acc: 0.8744 - val_binary_crossentropy: 0.3362
# Epoch 6/10
#  - 4s - loss: 0.1006 - acc: 0.9692 - binary_crossentropy: 0.1006 - val_loss: 0.3654 - val_acc: 0.8708 - val_binary_crossentropy: 0.3654
# Epoch 7/10
#  - 4s - loss: 0.0836 - acc: 0.9753 - binary_crossentropy: 0.0836 - val_loss: 0.3999 - val_acc: 0.8671 - val_binary_crossentropy: 0.3999
# Epoch 8/10
#  - 5s - loss: 0.0693 - acc: 0.9814 - binary_crossentropy: 0.0693 - val_loss: 0.4384 - val_acc: 0.8639 - val_binary_crossentropy: 0.4384
# Epoch 9/10
#  - 5s - loss: 0.0533 - acc: 0.9875 - binary_crossentropy: 0.0533 - val_loss: 0.4732 - val_acc: 0.8622 - val_binary_crossentropy: 0.4732
# Epoch 10/10
#  - 4s - loss: 0.0409 - acc: 0.9916 - binary_crossentropy: 0.0409 - val_loss: 0.5148 - val_acc: 0.8601 - val_binary_crossentropy: 0.5148

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_10 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.5800 - acc: 0.7443 - binary_crossentropy: 0.5800 - val_loss: 0.4538 - val_acc: 0.8514 - val_binary_crossentropy: 0.4538
# Epoch 2/20
#  - 6s - loss: 0.3532 - acc: 0.8929 - binary_crossentropy: 0.3532 - val_loss: 0.3361 - val_acc: 0.8814 - val_binary_crossentropy: 0.3361
# Epoch 3/20
#  - 3s - loss: 0.2565 - acc: 0.9194 - binary_crossentropy: 0.2565 - val_loss: 0.2976 - val_acc: 0.8866 - val_binary_crossentropy: 0.2976
# Epoch 4/20
#  - 3s - loss: 0.2095 - acc: 0.9327 - binary_crossentropy: 0.2095 - val_loss: 0.2868 - val_acc: 0.8867 - val_binary_crossentropy: 0.2868
# Epoch 5/20
#  - 3s - loss: 0.1800 - acc: 0.9424 - binary_crossentropy: 0.1800 - val_loss: 0.2856 - val_acc: 0.8872 - val_binary_crossentropy: 0.2856
# Epoch 6/20
#  - 3s - loss: 0.1599 - acc: 0.9496 - binary_crossentropy: 0.1599 - val_loss: 0.2909 - val_acc: 0.8861 - val_binary_crossentropy: 0.2909
# Epoch 7/20
#  - 3s - loss: 0.1425 - acc: 0.9553 - binary_crossentropy: 0.1425 - val_loss: 0.2987 - val_acc: 0.8832 - val_binary_crossentropy: 0.2987
# Epoch 8/20
#  - 3s - loss: 0.1282 - acc: 0.9616 - binary_crossentropy: 0.1282 - val_loss: 0.3113 - val_acc: 0.8783 - val_binary_crossentropy: 0.3113
# Epoch 9/20
#  - 4s - loss: 0.1167 - acc: 0.9652 - binary_crossentropy: 0.1167 - val_loss: 0.3216 - val_acc: 0.8760 - val_binary_crossentropy: 0.3216
# Epoch 10/20
#  - 3s - loss: 0.1059 - acc: 0.9693 - binary_crossentropy: 0.1059 - val_loss: 0.3376 - val_acc: 0.8736 - val_binary_crossentropy: 0.3376
# Epoch 11/20
#  - 3s - loss: 0.0977 - acc: 0.9724 - binary_crossentropy: 0.0977 - val_loss: 0.3509 - val_acc: 0.8721 - val_binary_crossentropy: 0.3509
# Epoch 12/20
#  - 4s - loss: 0.0896 - acc: 0.9754 - binary_crossentropy: 0.0896 - val_loss: 0.3666 - val_acc: 0.8691 - val_binary_crossentropy: 0.3666
# Epoch 13/20
#  - 3s - loss: 0.0816 - acc: 0.9792 - binary_crossentropy: 0.0816 - val_loss: 0.3801 - val_acc: 0.8682 - val_binary_crossentropy: 0.3801
# Epoch 14/20
#  - 3s - loss: 0.0746 - acc: 0.9820 - binary_crossentropy: 0.0746 - val_loss: 0.3971 - val_acc: 0.8678 - val_binary_crossentropy: 0.3971
# Epoch 15/20
#  - 3s - loss: 0.0691 - acc: 0.9842 - binary_crossentropy: 0.0691 - val_loss: 0.4143 - val_acc: 0.8653 - val_binary_crossentropy: 0.4143
# Epoch 16/20
#  - 3s - loss: 0.0639 - acc: 0.9860 - binary_crossentropy: 0.0639 - val_loss: 0.4373 - val_acc: 0.8646 - val_binary_crossentropy: 0.4373
# Epoch 17/20
#  - 3s - loss: 0.0586 - acc: 0.9888 - binary_crossentropy: 0.0586 - val_loss: 0.4513 - val_acc: 0.8614 - val_binary_crossentropy: 0.4513
# Epoch 18/20
#  - 3s - loss: 0.0538 - acc: 0.9902 - binary_crossentropy: 0.0538 - val_loss: 0.4690 - val_acc: 0.8612 - val_binary_crossentropy: 0.4690
# Epoch 19/20
#  - 3s - loss: 0.0492 - acc: 0.9916 - binary_crossentropy: 0.0492 - val_loss: 0.4889 - val_acc: 0.8590 - val_binary_crossentropy: 0.4889
# Epoch 20/20
#  - 3s - loss: 0.0452 - acc: 0.9929 - binary_crossentropy: 0.0452 - val_loss: 0.5070 - val_acc: 0.8593 - val_binary_crossentropy: 0.5070

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 512)               5120512
# _________________________________________________________________
# dense_13 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 19s - loss: 0.3476 - acc: 0.8494 - binary_crossentropy: 0.3476 - val_loss: 0.2828 - val_acc: 0.8858 - val_binary_crossentropy: 0.2828
# Epoch 2/20
#  - 16s - loss: 0.1364 - acc: 0.9504 - binary_crossentropy: 0.1364 - val_loss: 0.3201 - val_acc: 0.8755 - val_binary_crossentropy: 0.3201
# Epoch 3/20
#  - 16s - loss: 0.0409 - acc: 0.9893 - binary_crossentropy: 0.0409 - val_loss: 0.4608 - val_acc: 0.8668 - val_binary_crossentropy: 0.4608
# Epoch 4/20
#  - 17s - loss: 0.0052 - acc: 0.9992 - binary_crossentropy: 0.0052 - val_loss: 0.5911 - val_acc: 0.8699 - val_binary_crossentropy: 0.5911
# Epoch 5/20
#  - 16s - loss: 6.0206e-04 - acc: 1.0000 - binary_crossentropy: 6.0206e-04 - val_loss: 0.6972 - val_acc: 0.8709 - val_binary_crossentropy: 0.6972
# Epoch 6/20
#  - 15s - loss: 1.8016e-04 - acc: 1.0000 - binary_crossentropy: 1.8016e-04 - val_loss: 0.7486 - val_acc: 0.8712 - val_binary_crossentropy: 0.7486
# Epoch 7/20
#  - 15s - loss: 1.1070e-04 - acc: 1.0000 - binary_crossentropy: 1.1070e-04 - val_loss: 0.7806 - val_acc: 0.8713 - val_binary_crossentropy: 0.7806
# Epoch 8/20
#  - 16s - loss: 7.7879e-05 - acc: 1.0000 - binary_crossentropy: 7.7879e-05 - val_loss: 0.8074 - val_acc: 0.8716 - val_binary_crossentropy: 0.8074
# Epoch 9/20
#  - 16s - loss: 5.8239e-05 - acc: 1.0000 - binary_crossentropy: 5.8239e-05 - val_loss: 0.8302 - val_acc: 0.8719 - val_binary_crossentropy: 0.8302
# Epoch 10/20
#  - 16s - loss: 4.5223e-05 - acc: 1.0000 - binary_crossentropy: 4.5223e-05 - val_loss: 0.8496 - val_acc: 0.8722 - val_binary_crossentropy: 0.8496
# Epoch 11/20
#  - 16s - loss: 3.6026e-05 - acc: 1.0000 - binary_crossentropy: 3.6026e-05 - val_loss: 0.8677 - val_acc: 0.8722 - val_binary_crossentropy: 0.8677
# Epoch 12/20
#  - 16s - loss: 2.9342e-05 - acc: 1.0000 - binary_crossentropy: 2.9342e-05 - val_loss: 0.8846 - val_acc: 0.8724 - val_binary_crossentropy: 0.8846
# Epoch 13/20
#  - 16s - loss: 2.4275e-05 - acc: 1.0000 - binary_crossentropy: 2.4275e-05 - val_loss: 0.9001 - val_acc: 0.8727 - val_binary_crossentropy: 0.9001
# Epoch 14/20
#  - 15s - loss: 2.0388e-05 - acc: 1.0000 - binary_crossentropy: 2.0388e-05 - val_loss: 0.9137 - val_acc: 0.8726 - val_binary_crossentropy: 0.9137
# Epoch 15/20
#  - 16s - loss: 1.7340e-05 - acc: 1.0000 - binary_crossentropy: 1.7340e-05 - val_loss: 0.9274 - val_acc: 0.8727 - val_binary_crossentropy: 0.9274
# Epoch 16/20
#  - 17s - loss: 1.4854e-05 - acc: 1.0000 - binary_crossentropy: 1.4854e-05 - val_loss: 0.9399 - val_acc: 0.8726 - val_binary_crossentropy: 0.9399
# Epoch 17/20
#  - 19s - loss: 1.2868e-05 - acc: 1.0000 - binary_crossentropy: 1.2868e-05 - val_loss: 0.9521 - val_acc: 0.8726 - val_binary_crossentropy: 0.9521
# Epoch 18/20
#  - 18s - loss: 1.1216e-05 - acc: 1.0000 - binary_crossentropy: 1.1216e-05 - val_loss: 0.9633 - val_acc: 0.8727 - val_binary_crossentropy: 0.9633
# Epoch 19/20
#  - 17s - loss: 9.8494e-06 - acc: 1.0000 - binary_crossentropy: 9.8494e-06 - val_loss: 0.9742 - val_acc: 0.8728 - val_binary_crossentropy: 0.9742
# Epoch 20/20
#  - 16s - loss: 8.7182e-06 - acc: 1.0000 - binary_crossentropy: 8.7182e-06 - val_loss: 0.9844 - val_acc: 0.8727 - val_binary_crossentropy: 0.9844

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 4s - loss: 0.5538 - acc: 0.7996 - binary_crossentropy: 0.5140 - val_loss: 0.4173 - val_acc: 0.8696 - val_binary_crossentropy: 0.3761
# Epoch 2/20
#  - 4s - loss: 0.3369 - acc: 0.8996 - binary_crossentropy: 0.2905 - val_loss: 0.3462 - val_acc: 0.8850 - val_binary_crossentropy: 0.2960
# Epoch 3/20
#  - 4s - loss: 0.2773 - acc: 0.9222 - binary_crossentropy: 0.2242 - val_loss: 0.3407 - val_acc: 0.8847 - val_binary_crossentropy: 0.2859
# Epoch 4/20
#  - 7s - loss: 0.2496 - acc: 0.9332 - binary_crossentropy: 0.1932 - val_loss: 0.3425 - val_acc: 0.8844 - val_binary_crossentropy: 0.2851
# Epoch 5/20
#  - 8s - loss: 0.2322 - acc: 0.9402 - binary_crossentropy: 0.1735 - val_loss: 0.3538 - val_acc: 0.8815 - val_binary_crossentropy: 0.2945
# Epoch 6/20
#  - 7s - loss: 0.2204 - acc: 0.9451 - binary_crossentropy: 0.1602 - val_loss: 0.3633 - val_acc: 0.8787 - val_binary_crossentropy: 0.3027
# Epoch 7/20
#  - 5s - loss: 0.2107 - acc: 0.9492 - binary_crossentropy: 0.1494 - val_loss: 0.3745 - val_acc: 0.8767 - val_binary_crossentropy: 0.3127
# Epoch 8/20
#  - 4s - loss: 0.2032 - acc: 0.9515 - binary_crossentropy: 0.1409 - val_loss: 0.3886 - val_acc: 0.8741 - val_binary_crossentropy: 0.3260
# Epoch 9/20
#  - 4s - loss: 0.1964 - acc: 0.9539 - binary_crossentropy: 0.1331 - val_loss: 0.4037 - val_acc: 0.8696 - val_binary_crossentropy: 0.3402
# Epoch 10/20
#  - 5s - loss: 0.1916 - acc: 0.9555 - binary_crossentropy: 0.1274 - val_loss: 0.4163 - val_acc: 0.8689 - val_binary_crossentropy: 0.3516
# Epoch 11/20
#  - 5s - loss: 0.1871 - acc: 0.9582 - binary_crossentropy: 0.1218 - val_loss: 0.4270 - val_acc: 0.8670 - val_binary_crossentropy: 0.3613
# Epoch 12/20
#  - 4s - loss: 0.1801 - acc: 0.9613 - binary_crossentropy: 0.1141 - val_loss: 0.4400 - val_acc: 0.8666 - val_binary_crossentropy: 0.3738
# Epoch 13/20
#  - 4s - loss: 0.1747 - acc: 0.9619 - binary_crossentropy: 0.1081 - val_loss: 0.4488 - val_acc: 0.8653 - val_binary_crossentropy: 0.3822
# Epoch 14/20
#  - 4s - loss: 0.1744 - acc: 0.9628 - binary_crossentropy: 0.1067 - val_loss: 0.4667 - val_acc: 0.8647 - val_binary_crossentropy: 0.3979
# Epoch 15/20
#  - 5s - loss: 0.1724 - acc: 0.9633 - binary_crossentropy: 0.1031 - val_loss: 0.4775 - val_acc: 0.8620 - val_binary_crossentropy: 0.4074
# Epoch 16/20
#  - 5s - loss: 0.1644 - acc: 0.9690 - binary_crossentropy: 0.0942 - val_loss: 0.4860 - val_acc: 0.8622 - val_binary_crossentropy: 0.4154
# Epoch 17/20
#  - 4s - loss: 0.1575 - acc: 0.9715 - binary_crossentropy: 0.0870 - val_loss: 0.5066 - val_acc: 0.8581 - val_binary_crossentropy: 0.4358
# Epoch 18/20
#  - 5s - loss: 0.1535 - acc: 0.9728 - binary_crossentropy: 0.0823 - val_loss: 0.5128 - val_acc: 0.8610 - val_binary_crossentropy: 0.4410
# Epoch 19/20
#  - 4s - loss: 0.1507 - acc: 0.9743 - binary_crossentropy: 0.0784 - val_loss: 0.5306 - val_acc: 0.8566 - val_binary_crossentropy: 0.4575
# Epoch 20/20
#  - 7s - loss: 0.1487 - acc: 0.9745 - binary_crossentropy: 0.0751 - val_loss: 0.5403 - val_acc: 0.8581 - val_binary_crossentropy: 0.4659

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=30,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 8s - loss: 0.4506 - acc: 0.7907 - binary_crossentropy: 0.4506 - val_loss: 0.3025 - val_acc: 0.8730 - val_binary_crossentropy: 0.3025
# Epoch 2/20
#  - 8s - loss: 0.2962 - acc: 0.8858 - binary_crossentropy: 0.2962 - val_loss: 0.2864 - val_acc: 0.8838 - val_binary_crossentropy: 0.2864
# Epoch 3/20
#  - 7s - loss: 0.2432 - acc: 0.9075 - binary_crossentropy: 0.2432 - val_loss: 0.3069 - val_acc: 0.8825 - val_binary_crossentropy: 0.3069
# Epoch 4/20
#  - 8s - loss: 0.2088 - acc: 0.9200 - binary_crossentropy: 0.2088 - val_loss: 0.3255 - val_acc: 0.8796 - val_binary_crossentropy: 0.3255
# Epoch 5/20
#  - 9s - loss: 0.1882 - acc: 0.9278 - binary_crossentropy: 0.1882 - val_loss: 0.3480 - val_acc: 0.8790 - val_binary_crossentropy: 0.3480
# Epoch 6/20
#  - 7s - loss: 0.1742 - acc: 0.9317 - binary_crossentropy: 0.1742 - val_loss: 0.3813 - val_acc: 0.8742 - val_binary_crossentropy: 0.3813
# Epoch 7/20
#  - 6s - loss: 0.1636 - acc: 0.9359 - binary_crossentropy: 0.1636 - val_loss: 0.4121 - val_acc: 0.8754 - val_binary_crossentropy: 0.4121
# Epoch 8/20
#  - 7s - loss: 0.1448 - acc: 0.9424 - binary_crossentropy: 0.1448 - val_loss: 0.4254 - val_acc: 0.8729 - val_binary_crossentropy: 0.4254
# Epoch 9/20
#  - 7s - loss: 0.1356 - acc: 0.9459 - binary_crossentropy: 0.1356 - val_loss: 0.4476 - val_acc: 0.8763 - val_binary_crossentropy: 0.4476
# Epoch 10/20
#  - 9s - loss: 0.1335 - acc: 0.9468 - binary_crossentropy: 0.1335 - val_loss: 0.4869 - val_acc: 0.8738 - val_binary_crossentropy: 0.4869
# Epoch 11/20
#  - 12s - loss: 0.1279 - acc: 0.9476 - binary_crossentropy: 0.1279 - val_loss: 0.5410 - val_acc: 0.8744 - val_binary_crossentropy: 0.5410
# Epoch 12/20
#  - 8s - loss: 0.1229 - acc: 0.9500 - binary_crossentropy: 0.1229 - val_loss: 0.5653 - val_acc: 0.8716 - val_binary_crossentropy: 0.5653
# Epoch 13/20
#  - 7s - loss: 0.1285 - acc: 0.9474 - binary_crossentropy: 0.1285 - val_loss: 0.5675 - val_acc: 0.8742 - val_binary_crossentropy: 0.5675
# Epoch 14/20
#  - 8s - loss: 0.1174 - acc: 0.9506 - binary_crossentropy: 0.1174 - val_loss: 0.6243 - val_acc: 0.8721 - val_binary_crossentropy: 0.6243
# Epoch 15/20
#  - 7s - loss: 0.1186 - acc: 0.9493 - binary_crossentropy: 0.1186 - val_loss: 0.5931 - val_acc: 0.8721 - val_binary_crossentropy: 0.5931
# Epoch 16/20
#  - 9s - loss: 0.1118 - acc: 0.9527 - binary_crossentropy: 0.1118 - val_loss: 0.6674 - val_acc: 0.8724 - val_binary_crossentropy: 0.6674
# Epoch 17/20
#  - 8s - loss: 0.1121 - acc: 0.9516 - binary_crossentropy: 0.1121 - val_loss: 0.7175 - val_acc: 0.8713 - val_binary_crossentropy: 0.7175
# Epoch 18/20
#  - 7s - loss: 0.1050 - acc: 0.9548 - binary_crossentropy: 0.1050 - val_loss: 0.7424 - val_acc: 0.8718 - val_binary_crossentropy: 0.7424
# Epoch 19/20
#  - 11s - loss: 0.1077 - acc: 0.9534 - binary_crossentropy: 0.1077 - val_loss: 0.6731 - val_acc: 0.8714 - val_binary_crossentropy: 0.6731
# Epoch 20/20
#  - 14s - loss: 0.1100 - acc: 0.9523 - binary_crossentropy: 0.1100 - val_loss: 0.7093 - val_acc: 0.8719 - val_binary_crossentropy: 0.7093

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
