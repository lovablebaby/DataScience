# %%
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np

# %%
sns.set(palette='hls', font_scale=1.5)

# %%
product = ('Burger', 'Pizza', 'Coke', 'Fry')
p_range = np.arange(len(product)) # 제품명의 길이(len) 확인

# sales range
sales = 10 * np.random.rand(len(product))

# error range
error = 0.5 * np.random.rand(len(product))

# xerr : error, alpha : opacity (투명도)
plt.barh(p_range, sales, xerr=error, alpha = 0.6)
plt.yticks(p_range, product)
plt.xlabel("Sales(million $)")
plt.ylabel("Product")
plt.show()

# %%
# the number of bar chart groups
n_groups = 4

# sales and std range on `15
sales_15 = 10 * np.random.rand(len(product))
std_15 = 0.5 * np.random.rand(len(product))

# sales and std range on `16
sales_16 = 15 * np.random.rand(len(product))
std_16 = 0.8 * np.random.rand(len(product))


# index, bar_width, opacity
index = np.arange(n_groups) # for labeling
bar_width = 0.4
opacity = 0.6


# error bar color
error_config = {'ecolor':'0.6'}


# sales_15 plot and, vertical bar graph
plt.bar(index, sales_15, bar_width, alpha=opacity, 
       yerr=std_15, error_kw=error_config,
        label='Sales on \'15')


# sales_16 plot
plt.bar(index+bar_width, sales_16, bar_width, alpha=opacity, 
       yerr=std_16, error_kw=error_config,
        label='Sales on \'16')

'''
# stacked bar chart
plt.bar(index,sales_16, bar_width, alpha=opacity, yerr=std_16,
       error_kw=error_config, bottom=sales_15, label='Sales on \'16')
'''

plt.xlabel('Product')
plt.ylabel('Sales(million $)')
plt.title('Product Sales on 2016 and 2017')

# set the label position on between two plots
plt.xticks(index+bar_width/2, product)

plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Scatter plot
#
# document : https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.scatter

# %%
# scatter plot
x = np.random.randn(100)
y = np.random.randn(100)

# %%
# make points on x,y

plt.scatter(x,y)
plt.show()

# %%
# set the style
plt.scatter(x,y, 
           s=np.random.randn(100)*500, 
           c=np.random.randn(100),
           edgecolor='r')
plt.show()

# %%
x=np.random.rand(5,5)
print x

plt.imshow(x)
plt.grid(False)
plt.show()
# Out:
# [[ 0.86441734  0.76863117  0.2852047   0.24121895  0.26426702]
#  [ 0.15997754  0.25913142  0.54814593  0.61369625  0.55214156]
#  [ 0.92762726  0.7794586   0.81328699  0.72780459  0.49202224]
#  [ 0.27858134  0.22198746  0.67130151  0.11519608  0.98909382]
#  [ 0.88677131  0.28867578  0.27690431  0.53611096  0.95984889]]
